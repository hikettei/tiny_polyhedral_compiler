# %% [markdown]
# ## ScheduleTree and Loop Transformations

# %%
import sys

sys.path.append("../")


print("Caten initialized.")

# %% [markdown]
# ## ScheduleNodeDomain
#
#
#
# TODO:
# P.stmt
# Dependence Graph Visualization
# Parallelism

# %% [markdown]
# ## ScheduleNodeBand
#
# TODO: Bandの操作一覧，
